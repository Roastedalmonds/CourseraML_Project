# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Family kadam\\Desktop\\property.csv')

# %%
df.shape
# Out:
# (34348, 23)

# %%
df.columns
# Out:
# Index(['area', 'bathroom_num', 'bedroom_num', 'city', 'desc', 'dev_name',
#        'floor_count', 'floor_num', 'furnishing', 'id', 'id_string', 'latitude',
#        'locality', 'longitude', 'post_date', 'poster_name', 'price', 'project',
#        'title', 'trans', 'type', 'url', 'user_type'],
#       dtype='object')

# %%
df.dropna(inplace = True)
df.drop(columns = ['id','furnishing','desc','post_date','floor_num','poster_name','id_string','project','trans','title','url','floor_count','user_type'],inplace=True)
df.drop(df[df['area'] < 200].index, inplace = True)

# %%
df.head()
# Out:
#     area  bathroom_num  bedroom_num    city            dev_name   latitude  \
# 2  635.0           2.0            1  Mumbai       Agarwal Group  19.467032
# 4  625.0           1.0            1  Mumbai    Millennium Group  19.360215
# 5  630.0           2.0            1  Mumbai   Poonam Developers  19.470536
# 6  690.0           2.0            1  Mumbai  Evershine Builders  19.468258
# 8  675.0           2.0            1  Mumbai       Bahavni Group  19.471421
#
#        locality  longitude  price       type
# 2         Virar  72.801612   8000  Apartment
# 4  Naigaon East  72.850167   9000  Apartment
# 5    Virar West  72.808309   8000  Apartment
# 6         Virar  72.800613   8500  Apartment
# 8         Virar  72.800880   9000  Apartment

# %%
df.describe()
# Out:
#                area  bathroom_num   bedroom_num      latitude     longitude  \
# count  15730.000000  15730.000000  15730.000000  15730.000000  15730.000000
# mean    1306.607184      2.377305      2.272219     17.532217     66.669435
# std      685.019657      0.853042      0.875793      5.354558     20.312594
# min      200.000000      1.000000      1.000000      0.000000      0.000000
# 25%      883.000000      2.000000      2.000000     19.043011     72.831335
# 50%     1165.000000      2.000000      2.000000     19.119813     72.865869
# 75%     1550.000000      3.000000      3.000000     19.171010     72.892030
# max     9500.000000      8.000000      5.000000     72.919793     77.346025
#
#               price
# count  1.573000e+04
# mean   7.484586e+04
# std    7.405873e+04
# min    2.500000e+03
# 25%    3.500000e+04
# 50%    5.400000e+04
# 75%    8.500000e+04
# max    1.150000e+06

# %%
df.head()
# Out:
#     area  bathroom_num  bedroom_num    city            dev_name   latitude  \
# 2  635.0           2.0            1  Mumbai       Agarwal Group  19.467032
# 4  625.0           1.0            1  Mumbai    Millennium Group  19.360215
# 5  630.0           2.0            1  Mumbai   Poonam Developers  19.470536
# 6  690.0           2.0            1  Mumbai  Evershine Builders  19.468258
# 8  675.0           2.0            1  Mumbai       Bahavni Group  19.471421
#
#        locality  longitude  price       type
# 2         Virar  72.801612   8000  Apartment
# 4  Naigaon East  72.850167   9000  Apartment
# 5    Virar West  72.808309   8000  Apartment
# 6         Virar  72.800613   8500  Apartment
# 8         Virar  72.800880   9000  Apartment

# %%
df.rename(columns= {'dev_name':'developer', 'price':'rent'},inplace = True)

# %%
df.reset_index(inplace = True)
df.drop(columns = 'index', inplace = True)

# %%
df.head()
# Out:
#     area  bathroom_num  bedroom_num    city           developer   latitude  \
# 0  635.0           2.0            1  Mumbai       Agarwal Group  19.467032
# 1  625.0           1.0            1  Mumbai    Millennium Group  19.360215
# 2  630.0           2.0            1  Mumbai   Poonam Developers  19.470536
# 3  690.0           2.0            1  Mumbai  Evershine Builders  19.468258
# 4  675.0           2.0            1  Mumbai       Bahavni Group  19.471421
#
#        locality  longitude  rent       type
# 0         Virar  72.801612  8000  Apartment
# 1  Naigaon East  72.850167  9000  Apartment
# 2    Virar West  72.808309  8000  Apartment
# 3         Virar  72.800613  8500  Apartment
# 4         Virar  72.800880  9000  Apartment

# %%
df.shape
# Out:
# (15730, 10)

# %%
df.describe()
# Out:
#                area  bathroom_num   bedroom_num      latitude     longitude  \
# count  15730.000000  15730.000000  15730.000000  15730.000000  15730.000000
# mean    1306.607184      2.377305      2.272219     17.532217     66.669435
# std      685.019657      0.853042      0.875793      5.354558     20.312594
# min      200.000000      1.000000      1.000000      0.000000      0.000000
# 25%      883.000000      2.000000      2.000000     19.043011     72.831335
# 50%     1165.000000      2.000000      2.000000     19.119813     72.865869
# 75%     1550.000000      3.000000      3.000000     19.171010     72.892030
# max     9500.000000      8.000000      5.000000     72.919793     77.346025
#
#                rent
# count  1.573000e+04
# mean   7.484586e+04
# std    7.405873e+04
# min    2.500000e+03
# 25%    3.500000e+04
# 50%    5.400000e+04
# 75%    8.500000e+04
# max    1.150000e+06

# %%
df.head()
# Out:
#     area  bathroom_num  bedroom_num    city           developer   latitude  \
# 0  635.0           2.0            1  Mumbai       Agarwal Group  19.467032
# 1  625.0           1.0            1  Mumbai    Millennium Group  19.360215
# 2  630.0           2.0            1  Mumbai   Poonam Developers  19.470536
# 3  690.0           2.0            1  Mumbai  Evershine Builders  19.468258
# 4  675.0           2.0            1  Mumbai       Bahavni Group  19.471421
#
#        locality  longitude  rent       type
# 0         Virar  72.801612  8000  Apartment
# 1  Naigaon East  72.850167  9000  Apartment
# 2    Virar West  72.808309  8000  Apartment
# 3         Virar  72.800613  8500  Apartment
# 4         Virar  72.800880  9000  Apartment
